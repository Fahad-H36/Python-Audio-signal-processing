# %% [markdown]
# ***TASK #3C***

# %% [markdown]
# #ENCODING FUNCTION
# takes audio file and message as inputs... and then saves the encoded file named encoded.wav

# %%
def encode(file,message):
  print("\nEncoding Starts..")
  audio = wave.open(file,mode="rb")
  frame_bytes = bytearray(list(audio.readframes(audio.getnframes())))
  string = message
  string = string + int((len(frame_bytes)-(len(string)*8*8))/8) *'#'
  bits = list(map(int, ''.join([bin(ord(i)).lstrip('0b').rjust(8,'0') for i in string])))
  for i, bit in enumerate(bits):
      frame_bytes[i] = (frame_bytes[i] & 254) | bit
  frame_modified = bytes(frame_bytes)
  newAudio =  wave.open(r'assets/encoded.wav', 'wb')
  newAudio.setparams(audio.getparams())
  newAudio.writeframes(frame_modified)

  newAudio.close()
  audio.close()
  print(" |---->succesfully encoded")

# %%
encode(r'/content/drive/MyDrive/Ex3-4/ex3/assets/Ex3_sound5.wav', "Father Christmas does not exist")
# Out:
# Encoding Starts..
#  |---->succesfully encoded

# %% [markdown]
# #DECODE FUNCTION
# TAKES AUDIO FILE AS INPUT AND PRINTS MESSAGE HIDDEN IN

# %%
import wave

def decode(file):
	print("\nDecoding Starts..")
	audio = wave.open(file, mode='rb')
	frame_bytes = bytearray(list(audio.readframes(audio.getnframes())))
	extracted = [frame_bytes[i] & 1 for i in range(len(frame_bytes))]
	string = "".join(chr(int("".join(map(str,extracted[i:i+8])),2)) for i in range(0,len(extracted),8))
	decoded = string.split("###")[0]
	print("Sucessfully decoded: "+decoded)

# %%
decode(r'/content/drive/MyDrive/Ex3-4/ex3/assets/encoded.wav')
# Out:
# Decoding Starts..
# Sucessfully decoded: Father Christmas does not exist
